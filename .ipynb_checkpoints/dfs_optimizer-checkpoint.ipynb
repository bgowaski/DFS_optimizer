# %%
import urllib, json
import pandas as pd
import re
from itertools import permutations
from pulp import *
LATEST_URL = "https://api.draftkings.com/draftgroups/v1/draftgroups/21434/draftables?format=json"
response = urllib.request.urlopen(LATEST_URL)
data = json.loads(response.read())
current = pd.DataFrame.from_dict(data["draftables"])
# Remove players that are out or questionable
current = current[current.status == "None"]

# %%
# Add flex position
flex = current[current.position.isin(["RB","WR","TE"])].copy()
flex.position = "FLEX"
current = pd.concat([current, flex])

# %%
current.head()
# Out:
#                                          competition     displayName  \
# 0  {'competitionId': 5523589, 'name': 'CLE @ NO',...    Alvin Kamara
# 1  {'competitionId': 5523589, 'name': 'CLE @ NO',...    Alvin Kamara
# 2  {'competitionId': 5523601, 'name': 'ARI @ LAR'...  Todd Gurley II
# 3  {'competitionId': 5523601, 'name': 'ARI @ LAR'...  Todd Gurley II
# 6  {'competitionId': 5523565, 'name': 'KC @ PIT',...   Antonio Brown
#
#   draftAlerts                                draftStatAttributes  draftableId  \
# 0          []  [{'id': 90, 'value': '32.0', 'sortValue': '32....     11239044
# 1          []  [{'id': 90, 'value': '32.0', 'sortValue': '32....     11239045
# 2          []  [{'id': 90, 'value': '29.5', 'sortValue': '29....     11239046
# 3          []  [{'id': 90, 'value': '29.5', 'sortValue': '29....     11239047
# 6          []  [{'id': 90, 'value': '20.0', 'sortValue': '20....     11239276
#
#   firstName  isDisabled  isSwappable   lastName newsStatus  ...  \
# 0     Alvin       False        False     Kamara   Breaking  ...
# 1     Alvin       False        False     Kamara   Breaking  ...
# 2      Todd       False        False  Gurley II   Breaking  ...
# 3      Todd       False        False  Gurley II   Breaking  ...
# 6   Antonio       False        False      Brown     Recent  ...
#
#                                        playerImage50  \
# 0  https://d327rxwuxd0q0c.cloudfront.net/m/nfl_50...
# 1  https://d327rxwuxd0q0c.cloudfront.net/m/nfl_50...
# 2  https://d327rxwuxd0q0c.cloudfront.net/m/nfl_50...
# 3  https://d327rxwuxd0q0c.cloudfront.net/m/nfl_50...
# 6  https://d327rxwuxd0q0c.cloudfront.net/m/nfl_50...
#
#                                        playerImage65  \
# 0  https://d327rxwuxd0q0c.cloudfront.net/m/nfl_65...
# 1  https://d327rxwuxd0q0c.cloudfront.net/m/nfl_65...
# 2  https://d327rxwuxd0q0c.cloudfront.net/m/nfl_65...
# 3  https://d327rxwuxd0q0c.cloudfront.net/m/nfl_65...
# 6  https://d327rxwuxd0q0c.cloudfront.net/m/nfl_65...
#
#                                      playerImageFull  position rosterSlotId  \
# 0  https://d327rxwuxd0q0c.cloudfront.net/nfl/play...        RB           67
# 1  https://d327rxwuxd0q0c.cloudfront.net/nfl/play...        RB           70
# 2  https://d327rxwuxd0q0c.cloudfront.net/nfl/play...        RB           67
# 3  https://d327rxwuxd0q0c.cloudfront.net/nfl/play...        RB           70
# 6  https://d327rxwuxd0q0c.cloudfront.net/nfl/play...        WR           68
#
#   salary     shortName status teamAbbreviation  teamId
# 0   9500     A. Kamara   None               NO     350
# 1   9500     A. Kamara   None               NO     350
# 2   9200  T. Gurley II   None              LAR     343
# 3   9200  T. Gurley II   None              LAR     343
# 6   8800      A. Brown   None              PIT     356
#
# [5 rows x 25 columns]

# %%
def get_float(l, key):
    """ Returns first float value from a list of dictionaries based on key. Defaults to 0.0 """
    for d in l:
        try:
            return float(d.get(key))
        except:
            pass
    return 0.0
points = [get_float(x, "value") for x in
  current.draftStatAttributes]
current["points"] = points

# %%
availables = current[["position", "displayName", "salary",
  "points"]].groupby(["position", "displayName", "salary",
  "points"]).agg("count")
availables = availables.reset_index()
availables[availables.position=="QB"].head(15)
# Out:
#     position         displayName  salary  points
# 335       QB         AJ McCarron    4600     0.0
# 336       QB          Alex Smith    6000    16.3
# 337       QB         Andrew Luck    6200    18.4
# 338       QB      Baker Mayfield    4600     9.8
# 339       QB  Ben Roethlisberger    6900    29.5
# 340       QB      Blaine Gabbert    4700     6.3
# 341       QB       Blake Bortles    5400    25.4
# 342       QB       Brandon Allen    4000     0.0
# 343       QB      Brandon Weeden    4600     0.0
# 344       QB         Brian Hoyer    4500     0.0
# 345       QB      Brock Osweiler    4500     0.0
# 346       QB       C.J. Beathard    4400     0.0
# 347       QB          Cam Newton    6600    24.9
# 348       QB        Carson Wentz    6400     0.0
# 349       QB         Case Keenum    5800    20.3

# %%
salaries = {}
points = {}
for pos in availables.position.unique():
    available_pos = availables[availables.position == pos]
    salary = list(available_pos[["displayName","salary"]].set_index("displayName").to_dict().values())[0]
    point = list(available_pos[["displayName","points"]].set_index("displayName").to_dict().values())[0]
    salaries[pos] = salary
    points[pos] = point

# %%
pos_num_available = {
    "QB": 1,
    "RB": 2,
    "WR": 3,
    "TE": 1,
    "FLEX": 1,
    "DST": 1
}

# %%
salaries
# Out:
# {'DST': {'49ers ': 2800,
#   'Bills ': 2100,
#   'Broncos ': 3300,
#   'Browns ': 2000,
#   'Buccaneers ': 2200,
#   'Cardinals ': 2100,
#   'Chargers ': 3600,
#   'Chiefs ': 2200,
#   'Colts ': 2300,
#   'Dolphins ': 3100,
#   'Eagles ': 3400,
#   'Falcons ': 2700,
#   'Jaguars ': 2800,
#   'Jets ': 2500,
#   'Lions ': 2300,
#   'Packers ': 2500,
#   'Panthers ': 2900,
#   'Patriots ': 3000,
#   'Raiders ': 2300,
#   'Rams ': 3700,
#   'Redskins ': 2700,
#   'Saints ': 3200,
#   'Steelers ': 2700,
#   'Texans ': 2600,
#   'Titans ': 2400,
#   'Vikings ': 2600},
#  'FLEX': {'A.J. Derby': 2500,
#   'Aaron Jones': 5000,
#   'Adam Humphries': 3400,
#   'Adam Thielen': 7100,
#   'Adrian Peterson': 5500,
#   'Alan Cross': 2500,
#   'Albert Wilson': 3700,
#   'Alex Armah': 3000,
#   'Alex Ellis': 2500,
#   'Alfred Blue': 3900,
#   'Alfred Morris': 3600,
#   'Alvin Kamara': 9500,
#   'Amari Cooper': 6600,
#   'Ameer Abdullah': 3600,
#   'Andre Holmes': 3200,
#   'Andre Roberts': 3000,
#   'Andy Janovich': 3000,
#   'Anthony Firkser': 2500,
#   'Anthony Sherman': 3000,
#   'Antonio Brown': 8800,
#   'Antonio Callaway': 3000,
#   'Antony Auclair': 2500,
#   'ArDarius Stewart': 3000,
#   'Austin Carr': 3200,
#   'Austin Ekeler': 4400,
#   'Austin Hooper': 2900,
#   'Austin Seferian-Jenkins': 3200,
#   'Beau Brinkley': 2500,
#   'Benjamin Watson': 3400,
#   'Bilal Powell': 5100,
#   'Bradley Marquez': 3000,
#   'Brandin Cooks': 6100,
#   'Brandon Bolden': 3000,
#   'Brandon LaFell': 3800,
#   'Brandon Powell': 3000,
#   'Brandon Zylstra': 3000,
#   'Bruce Ellington': 3800,
#   'Buddy Howell': 3000,
#   'C.J. Anderson': 3900,
#   'C.J. Ham': 3000,
#   'Calvin Ridley': 3700,
#   'Cameron Artis-Payne': 3000,
#   'Cameron Batson': 3000,
#   'Cameron Brate': 2800,
#   'Cameron Meredith': 4100,
#   'Carlos Hyde': 4900,
#   'Chad Hansen': 3000,
#   'Chad Williams': 3200,
#   'Charles Clay': 3100,
#   'Chase Edmonds': 4500,
#   'Chester Rogers': 3300,
#   'Chris Conley': 3300,
#   'Chris Herndon': 2500,
#   'Chris Hogan': 5400,
#   'Chris Ivory': 4200,
#   'Chris Manhertz': 2500,
#   'Chris Thompson': 5900,
#   'Christian Kirk': 3600,
#   'Christian McCaffrey': 7000,
#   'Christine Michael': 3200,
#   'Cole Wick': 2500,
#   'Cooper Kupp': 5500,
#   'Cordarrelle Patterson': 3400,
#   'Corey Davis': 5100,
#   'Corey Grant': 4300,
#   'Courtland Sutton': 3500,
#   'D.J. Chark Jr.': 3000,
#   'D.J. Moore': 4000,
#   'DaeSean Hamilton': 3000,
#   'Dallas Goedert': 2700,
#   'Damien Williams': 3000,
#   'Damion Ratley': 3000,
#   'Dan Arnold': 2500,
#   'Danny Amendola': 4600,
#   'Dante Pettis': 4000,
#   'Darius Jackson': 3000,
#   'Darius Jennings': 3000,
#   'Darrel Williams': 3000,
#   'Darren Fells': 2500,
#   'Darrius Heyward-Bey': 3100,
#   'Davante Adams': 6800,
#   'David Johnson': 8200,
#   'David Njoku': 3000,
#   "De'Anthony Thomas": 3300,
#   'DeAndre Carter': 3000,
#   'DeAndre Hopkins': 8000,
#   'DeAndre Washington': 3000,
#   'DeSean Jackson': 4900,
#   'DeVante Parker': 4500,
#   'Dede Westbrook': 4500,
#   'Demarcus Robinson': 3100,
#   'Demaryius Thomas': 5600,
#   'Demetrius Harris': 2700,
#   'Derek Carrier': 2500,
#   'Derrick Coleman': 3000,
#   'Derrick Henry': 5200,
#   'Derrick Willies': 3000,
#   'Detrez Newsome': 3000,
#   'Devin Funchess': 4700,
#   'Devontae Booker': 3700,
#   'Dion Lewis': 5000,
#   'Donte Moncrief': 3700,
#   'Doug Martin': 3900,
#   'Duke Johnson Jr.': 4200,
#   'Durham Smythe': 2500,
#   'Dwayne Allen': 2600,
#   'Dwayne Harris': 3000,
#   'Elijah Hood': 3000,
#   'Emmanuel Sanders': 6200,
#   'Equanimeous St. Brown': 3000,
#   'Eric Ebron': 3500,
#   'Eric Saubert': 2500,
#   'Eric Tomlinson': 2500,
#   'Erik Swoope': 2500,
#   'Frank Gore': 3900,
#   'Freddie Martino': 3000,
#   'Gabe Holmes': 2500,
#   'Garrett Celek': 2600,
#   'Gavin Escobar': 2500,
#   'George Kittle': 3800,
#   'Gerald Everett': 2500,
#   'Geremy Davis': 3000,
#   'Geronimo Allison': 3800,
#   'Golden Tate': 6500,
#   'Hakeem Valles': 2700,
#   'Ian Thomas': 2900,
#   'Isaiah Crowell': 4600,
#   'Isaiah McKenzie': 3000,
#   'Ito Smith': 3000,
#   "J'Mon Moore": 3000,
#   'J.J. Jones': 3000,
#   'J.J. Nelson': 3300,
#   'Jacquizz Rodgers': 3500,
#   'Jake Butt': 2700,
#   'Jakeem Grant': 3900,
#   'Jalen Richard': 3400,
#   'Jamaal Williams': 5200,
#   'James Conner': 6700,
#   'James Develin': 3000,
#   "James O'Shaughnessy": 2500,
#   'James Washington': 3800,
#   'James White': 4500,
#   'James Winchester': 2500,
#   'Jamison Crowder': 4900,
#   'Jared Cook': 3600,
#   'Jarius Wright': 3800,
#   'Jarvis Landry': 6300,
#   'Jason Croom': 2500,
#   'Jaydon Mickens': 3000,
#   'Jaylen Samuels': 3000,
#   'Jeff Heuerman': 2500,
#   'Jeremy Kerley': 3500,
#   'Jeremy Sprinkle': 2500,
#   'Jermaine Kearse': 4000,
#   'Jesse James': 2800,
#   'Jimmy Graham': 4800,
#   'John Kelly': 4500,
#   'Johnny Mundt': 2500,
#   'Jonathan Williams': 3800,
#   'Jonnu Smith': 3100,
#   'Jordan Akins': 2600,
#   'Jordan Leggett': 2600,
#   'Jordan Reed': 5000,
#   'Jordan Thomas': 2500,
#   'Jordan Wilkins': 4400,
#   'Jordy Nelson': 5000,
#   'Josh Doctson': 4000,
#   'Josh Hill': 2500,
#   'Josh Reynolds': 3000,
#   'Joshua Perkins': 2500,
#   'JuJu Smith-Schuster': 6400,
#   'Julio Jones': 8400,
#   'Justin Davis': 3000,
#   'Justin Hardy': 3000,
#   'Justin Hunter': 3000,
#   'Justin Watson': 3000,
#   'Kalen Ballage': 3300,
#   'Kareem Hunt': 6200,
#   'Keelan Cole': 4900,
#   'Keenan Allen': 7800,
#   'Keith Smith': 3000,
#   'Kelvin Benjamin': 4600,
#   'Kendrick Bourne': 3000,
#   'Kenny Golladay': 4800,
#   'Kenny Stills': 5700,
#   'Kenyan Drake': 5800,
#   'Keon Hatcher': 3000,
#   'Kerryon Johnson': 4200,
#   'Kevin McDermott': 2500,
#   'Khari Lee': 2500,
#   'Kyle Juszczyk': 3200,
#   'Kyle Nelson': 2500,
#   'Kyle Rudolph': 4200,
#   'Lamar Miller': 5400,
#   'Lance Kendricks': 2500,
#   'Laquon Treadwell': 3300,
#   'Latavius Murray': 4600,
#   'LeGarrette Blount': 4500,
#   'Lee Smith': 2500,
#   'Levine Toilolo': 2500,
#   'Logan Paulsen': 2500,
#   'Logan Thomas': 2500,
#   'Luke Stocker': 2500,
#   'Luke Willson': 3000,
#   'Malcolm Brown': 3500,
#   'Marcedes Lewis': 2500,
#   'Marcus Johnson': 3000,
#   'Marcus Kemp': 3000,
#   'Marcus Murphy': 3000,
#   'Markus Wheaton': 3000,
#   'Marquez Valdes-Scantling': 3000,
#   'Marshawn Lynch': 5100,
#   'Marvin Hall': 3000,
#   'Matt Breida': 4800,
#   'Matt Hazel': 3000,
#   'Matt LaCosse': 2500,
#   'Matthew Slater': 3000,
#   'Melvin Gordon III': 7400,
#   'Michael Roberts': 2500,
#   'Michael Thomas': 8600,
#   'Mike Evans': 7300,
#   'Mike Gesicki': 2800,
#   'Mike Gillislee': 3300,
#   'Mike Williams': 3700,
#   'Mohamed Sanu': 4000,
#   'Nelson Agholor': 6100,
#   'Nick Bellore': 3000,
#   'Nick Chubb': 3800,
#   'Niles Paul': 2500,
#   'Nyheim Hines': 4100,
#   'O.J. Howard': 3200,
#   'Orson Charles': 2500,
#   'Patrick DiMarco': 3000,
#   'Peyton Barber': 4000,
#   'Phillip Dorsett': 4500,
#   'Phillip Lindsay': 4400,
#   'Pierre Garcon': 5000,
#   'Quincy Enunwa': 4700,
#   'Raheem Mostert': 3000,
#   'Randall Cobb': 4600,
#   'Rashad Greene Sr.': 3000,
#   'Rashard Higgins': 3000,
#   'Rex Burkhead': 4400,
#   'Richie James Jr.': 3000,
#   'Ricky Ortiz': 3000,
#   'Ricky Seals-Jones': 2900,
#   'Riley McCarron': 3000,
#   'Rishard Matthews': 4200,
#   'Rob Gronkowski': 7000,
#   'Robby Anderson': 5400,
#   'Robert Foster': 3000,
#   'Robert Tonyan': 2500,
#   'Robert Woods': 5900,
#   'Roc Thomas': 3000,
#   'Ronald Jones II': 3900,
#   'Roosevelt Nix': 3000,
#   'Royce Freeman': 4300,
#   'Russell Gage': 3000,
#   'Ryan Grant': 4300,
#   'Ryan Griffin': 2700,
#   'Ryan Hewitt': 2500,
#   'Ryan Switzer': 3000,
#   'Samaje Perine': 3500,
#   'Sammy Watkins': 4600,
#   'Sean Culkin': 2500,
#   'Senorise Perry': 3000,
#   'Seth Roberts': 3000,
#   'Shaun Wilson': 3000,
#   'Shelton Gibson': 3000,
#   'Sony Michel': 4100,
#   'Stacy Coley': 3000,
#   'Stefon Diggs': 6900,
#   'Stevan Ridley': 3500,
#   'T.J. Logan': 3500,
#   'T.Y. Hilton': 6700,
#   'TJ Jones': 3200,
#   'Tajae Sharpe': 3300,
#   'Tanner McEvoy': 3000,
#   'Taywan Taylor': 3600,
#   'Ted Ginn Jr.': 4800,
#   'Terrelle Pryor': 3700,
#   'Tevin Coleman': 5300,
#   'Theo Riddick': 4000,
#   'Tim Patrick': 3000,
#   'Todd Gurley II': 9200,
#   'Tommy Bohanon': 3000,
#   'Torrey Smith': 3500,
#   'Travis Kelce': 5900,
#   "Tre'Quan Smith": 3400,
#   'Trent Sherfield': 3000,
#   'Trent Taylor': 3900,
#   'Trenton Cannon': 3000,
#   'Ty Montgomery': 3700,
#   'Tyler Conklin': 2500,
#   'Tyler Ervin': 3000,
#   'Tyler Higbee': 2800,
#   'Tyreek Hill': 7600,
#   'Tyrell Williams': 4400,
#   'Vance McDonald': 3100,
#   'Vernon Davis': 3300,
#   'Virgil Green': 2700,
#   'Vyncint Smith': 3000,
#   'Wendell Smallwood': 3000,
#   'Will Fuller V': 5300,
#   'Xavier Grimble': 2500,
#   'Zach Ertz': 6100,
#   'Zach Line': 3000,
#   'Zach Pascal': 3000,
#   'Zay Jones': 3800},
#  'QB': {'AJ McCarron': 4600,
#   'Alex Smith': 6000,
#   'Andrew Luck': 6200,
#   'Baker Mayfield': 4600,
#   'Ben Roethlisberger': 6900,
#   'Blaine Gabbert': 4700,
#   'Blake Bortles': 5400,
#   'Brandon Allen': 4000,
#   'Brandon Weeden': 4600,
#   'Brian Hoyer': 4500,
#   'Brock Osweiler': 4500,
#   'C.J. Beathard': 4400,
#   'Cam Newton': 6600,
#   'Carson Wentz': 6400,
#   'Case Keenum': 5800,
#   'Chad Henne': 4500,
#   'Chad Kelly': 4400,
#   'Cody Kessler': 4000,
#   'Colt McCoy': 4500,
#   'David Fales': 4000,
#   'DeShone Kizer': 4500,
#   'Derek Carr': 5500,
#   'Deshaun Watson': 6300,
#   'Drew Brees': 7200,
#   'Geno Smith': 5000,
#   'Jacoby Brissett': 5000,
#   'Jared Goff': 6300,
#   'Jimmy Garoppolo': 6000,
#   'Joe Webb III': 4000,
#   'Josh Allen': 4600,
#   'Josh McCown': 4800,
#   'Josh Rosen': 4500,
#   'Joshua Dobbs': 4000,
#   'Kevin Hogan': 4400,
#   'Kirk Cousins': 6400,
#   'Kyle Sloter': 4000,
#   'Luke Falk': 4000,
#   'Mason Rudolph': 4700,
#   'Matt Cassel': 4600,
#   'Matt Ryan': 5700,
#   'Matt Schaub': 4000,
#   'Matthew Stafford': 6100,
#   'Mike Glennon': 4100,
#   'Nate Sudfeld': 4000,
#   'Nathan Peterman': 4300,
#   'Nick Foles': 5700,
#   'Patrick Mahomes': 6100,
#   'Philip Rivers': 6700,
#   'Ryan Fitzpatrick': 5500,
#   'Ryan Griffin': 4500,
#   'Ryan Tannehill': 5300,
#   'Sam Bradford': 4800,
#   'Sam Darnold': 5100,
#   'Sean Mannion': 4400,
#   'Taylor Heinicke': 4000,
#   'Taysom Hill': 4000,
#   'Teddy Bridgewater': 4900,
#   'Tim Boyle': 4000,
#   'Tom Brady': 6500,
#   'Trevor Siemian': 4600},
#  'RB': {'Aaron Jones': 5000,
#   'Adrian Peterson': 5500,
#   'Alex Armah': 3000,
#   'Alfred Blue': 3900,
#   'Alfred Morris': 3600,
#   'Alvin Kamara': 9500,
#   'Ameer Abdullah': 3600,
#   'Andy Janovich': 3000,
#   'Anthony Sherman': 3000,
#   'Austin Ekeler': 4400,
#   'Bilal Powell': 5100,
#   'Brandon Bolden': 3000,
#   'Buddy Howell': 3000,
#   'C.J. Anderson': 3900,
#   'C.J. Ham': 3000,
#   'Cameron Artis-Payne': 3000,
#   'Carlos Hyde': 4900,
#   'Chase Edmonds': 4500,
#   'Chris Ivory': 4200,
#   'Chris Thompson': 5900,
#   'Christian McCaffrey': 7000,
#   'Christine Michael': 3200,
#   'Corey Grant': 4300,
#   'Damien Williams': 3000,
#   'Darius Jackson': 3000,
#   'Darrel Williams': 3000,
#   'David Johnson': 8200,
#   'DeAndre Washington': 3000,
#   'Derrick Coleman': 3000,
#   'Derrick Henry': 5200,
#   'Detrez Newsome': 3000,
#   'Devontae Booker': 3700,
#   'Dion Lewis': 5000,
#   'Doug Martin': 3900,
#   'Duke Johnson Jr.': 4200,
#   'Elijah Hood': 3000,
#   'Frank Gore': 3900,
#   'Isaiah Crowell': 4600,
#   'Ito Smith': 3000,
#   'Jacquizz Rodgers': 3500,
#   'Jalen Richard': 3400,
#   'Jamaal Williams': 5200,
#   'James Conner': 6700,
#   'James Develin': 3000,
#   'James White': 4500,
#   'Jaylen Samuels': 3000,
#   'John Kelly': 4500,
#   'Jonathan Williams': 3800,
#   'Jordan Wilkins': 4400,
#   'Justin Davis': 3000,
#   'Kalen Ballage': 3300,
#   'Kareem Hunt': 6200,
#   'Keith Smith': 3000,
#   'Kenyan Drake': 5800,
#   'Kerryon Johnson': 4200,
#   'Kyle Juszczyk': 3200,
#   'Lamar Miller': 5400,
#   'Latavius Murray': 4600,
#   'LeGarrette Blount': 4500,
#   'Malcolm Brown': 3500,
#   'Marcus Murphy': 3000,
#   'Marshawn Lynch': 5100,
#   'Matt Breida': 4800,
#   'Melvin Gordon III': 7400,
#   'Mike Gillislee': 3300,
#   'Nick Bellore': 3000,
#   'Nick Chubb': 3800,
#   'Nyheim Hines': 4100,
#   'Patrick DiMarco': 3000,
#   'Peyton Barber': 4000,
#   'Phillip Lindsay': 4400,
#   'Raheem Mostert': 3000,
#   'Rex Burkhead': 4400,
#   'Ricky Ortiz': 3000,
#   'Roc Thomas': 3000,
#   'Ronald Jones II': 3900,
#   'Roosevelt Nix': 3000,
#   'Royce Freeman': 4300,
#   'Samaje Perine': 3500,
#   'Senorise Perry': 3000,
#   'Shaun Wilson': 3000,
#   'Sony Michel': 4100,
#   'Stevan Ridley': 3500,
#   'T.J. Logan': 3500,
#   'Tevin Coleman': 5300,
#   'Theo Riddick': 4000,
#   'Todd Gurley II': 9200,
#   'Tommy Bohanon': 3000,
#   'Trenton Cannon': 3000,
#   'Ty Montgomery': 3700,
#   'Tyler Ervin': 3000,
#   'Wendell Smallwood': 3000,
#   'Zach Line': 3000},
#  'TE': {'A.J. Derby': 2500,
#   'Alan Cross': 2500,
#   'Alex Ellis': 2500,
#   'Anthony Firkser': 2500,
#   'Antony Auclair': 2500,
#   'Austin Hooper': 2900,
#   'Austin Seferian-Jenkins': 3200,
#   'Beau Brinkley': 2500,
#   'Benjamin Watson': 3400,
#   'Cameron Brate': 2800,
#   'Charles Clay': 3100,
#   'Chris Herndon': 2500,
#   'Chris Manhertz': 2500,
#   'Cole Wick': 2500,
#   'Dallas Goedert': 2700,
#   'Dan Arnold': 2500,
#   'Darren Fells': 2500,
#   'David Njoku': 3000,
#   'Demetrius Harris': 2700,
#   'Derek Carrier': 2500,
#   'Durham Smythe': 2500,
#   'Dwayne Allen': 2600,
#   'Eric Ebron': 3500,
#   'Eric Saubert': 2500,
#   'Eric Tomlinson': 2500,
#   'Erik Swoope': 2500,
#   'Gabe Holmes': 2500,
#   'Garrett Celek': 2600,
#   'Gavin Escobar': 2500,
#   'George Kittle': 3800,
#   'Gerald Everett': 2500,
#   'Hakeem Valles': 2700,
#   'Ian Thomas': 2900,
#   'Jake Butt': 2700,
#   "James O'Shaughnessy": 2500,
#   'James Winchester': 2500,
#   'Jared Cook': 3600,
#   'Jason Croom': 2500,
#   'Jeff Heuerman': 2500,
#   'Jeremy Sprinkle': 2500,
#   'Jesse James': 2800,
#   'Jimmy Graham': 4800,
#   'Johnny Mundt': 2500,
#   'Jonnu Smith': 3100,
#   'Jordan Akins': 2600,
#   'Jordan Leggett': 2600,
#   'Jordan Reed': 5000,
#   'Jordan Thomas': 2500,
#   'Josh Hill': 2500,
#   'Joshua Perkins': 2500,
#   'Kevin McDermott': 2500,
#   'Khari Lee': 2500,
#   'Kyle Nelson': 2500,
#   'Kyle Rudolph': 4200,
#   'Lance Kendricks': 2500,
#   'Lee Smith': 2500,
#   'Levine Toilolo': 2500,
#   'Logan Paulsen': 2500,
#   'Logan Thomas': 2500,
#   'Luke Stocker': 2500,
#   'Luke Willson': 3000,
#   'Marcedes Lewis': 2500,
#   'Matt LaCosse': 2500,
#   'Michael Roberts': 2500,
#   'Mike Gesicki': 2800,
#   'Niles Paul': 2500,
#   'O.J. Howard': 3200,
#   'Orson Charles': 2500,
#   'Ricky Seals-Jones': 2900,
#   'Rob Gronkowski': 7000,
#   'Robert Tonyan': 2500,
#   'Ryan Griffin': 2700,
#   'Ryan Hewitt': 2500,
#   'Sean Culkin': 2500,
#   'Travis Kelce': 5900,
#   'Tyler Conklin': 2500,
#   'Tyler Higbee': 2800,
#   'Vance McDonald': 3100,
#   'Vernon Davis': 3300,
#   'Virgil Green': 2700,
#   'Xavier Grimble': 2500,
#   'Zach Ertz': 6100},
#  'WR': {'Adam Humphries': 3400,
#   'Adam Thielen': 7100,
#   'Albert Wilson': 3700,
#   'Amari Cooper': 6600,
#   'Andre Holmes': 3200,
#   'Andre Roberts': 3000,
#   'Antonio Brown': 8800,
#   'Antonio Callaway': 3000,
#   'ArDarius Stewart': 3000,
#   'Austin Carr': 3200,
#   'Bradley Marquez': 3000,
#   'Brandin Cooks': 6100,
#   'Brandon LaFell': 3800,
#   'Brandon Powell': 3000,
#   'Brandon Zylstra': 3000,
#   'Bruce Ellington': 3800,
#   'Calvin Ridley': 3700,
#   'Cameron Batson': 3000,
#   'Cameron Meredith': 4100,
#   'Chad Hansen': 3000,
#   'Chad Williams': 3200,
#   'Chester Rogers': 3300,
#   'Chris Conley': 3300,
#   'Chris Hogan': 5400,
#   'Christian Kirk': 3600,
#   'Cooper Kupp': 5500,
#   'Cordarrelle Patterson': 3400,
#   'Corey Davis': 5100,
#   'Courtland Sutton': 3500,
#   'D.J. Chark Jr.': 3000,
#   'D.J. Moore': 4000,
#   'DaeSean Hamilton': 3000,
#   'Damion Ratley': 3000,
#   'Danny Amendola': 4600,
#   'Dante Pettis': 4000,
#   'Darius Jennings': 3000,
#   'Darrius Heyward-Bey': 3100,
#   'Davante Adams': 6800,
#   "De'Anthony Thomas": 3300,
#   'DeAndre Carter': 3000,
#   'DeAndre Hopkins': 8000,
#   'DeSean Jackson': 4900,
#   'DeVante Parker': 4500,
#   'Dede Westbrook': 4500,
#   'Demarcus Robinson': 3100,
#   'Demaryius Thomas': 5600,
#   'Derrick Willies': 3000,
#   'Devin Funchess': 4700,
#   'Donte Moncrief': 3700,
#   'Dwayne Harris': 3000,
#   'Emmanuel Sanders': 6200,
#   'Equanimeous St. Brown': 3000,
#   'Freddie Martino': 3000,
#   'Geremy Davis': 3000,
#   'Geronimo Allison': 3800,
#   'Golden Tate': 6500,
#   'Isaiah McKenzie': 3000,
#   "J'Mon Moore": 3000,
#   'J.J. Jones': 3000,
#   'J.J. Nelson': 3300,
#   'Jakeem Grant': 3900,
#   'James Washington': 3800,
#   'Jamison Crowder': 4900,
#   'Jarius Wright': 3800,
#   'Jarvis Landry': 6300,
#   'Jaydon Mickens': 3000,
#   'Jeremy Kerley': 3500,
#   'Jermaine Kearse': 4000,
#   'Jordy Nelson': 5000,
#   'Josh Doctson': 4000,
#   'Josh Reynolds': 3000,
#   'JuJu Smith-Schuster': 6400,
#   'Julio Jones': 8400,
#   'Justin Hardy': 3000,
#   'Justin Hunter': 3000,
#   'Justin Watson': 3000,
#   'Keelan Cole': 4900,
#   'Keenan Allen': 7800,
#   'Kelvin Benjamin': 4600,
#   'Kendrick Bourne': 3000,
#   'Kenny Golladay': 4800,
#   'Kenny Stills': 5700,
#   'Keon Hatcher': 3000,
#   'Laquon Treadwell': 3300,
#   'Marcus Johnson': 3000,
#   'Marcus Kemp': 3000,
#   'Markus Wheaton': 3000,
#   'Marquez Valdes-Scantling': 3000,
#   'Marvin Hall': 3000,
#   'Matt Hazel': 3000,
#   'Matthew Slater': 3000,
#   'Michael Thomas': 8600,
#   'Mike Evans': 7300,
#   'Mike Williams': 3700,
#   'Mohamed Sanu': 4000,
#   'Nelson Agholor': 6100,
#   'Phillip Dorsett': 4500,
#   'Pierre Garcon': 5000,
#   'Quincy Enunwa': 4700,
#   'Randall Cobb': 4600,
#   'Rashad Greene Sr.': 3000,
#   'Rashard Higgins': 3000,
#   'Richie James Jr.': 3000,
#   'Riley McCarron': 3000,
#   'Rishard Matthews': 4200,
#   'Robby Anderson': 5400,
#   'Robert Foster': 3000,
#   'Robert Woods': 5900,
#   'Russell Gage': 3000,
#   'Ryan Grant': 4300,
#   'Ryan Switzer': 3000,
#   'Sammy Watkins': 4600,
#   'Seth Roberts': 3000,
#   'Shelton Gibson': 3000,
#   'Stacy Coley': 3000,
#   'Stefon Diggs': 6900,
#   'T.Y. Hilton': 6700,
#   'TJ Jones': 3200,
#   'Tajae Sharpe': 3300,
#   'Tanner McEvoy': 3000,
#   'Taywan Taylor': 3600,
#   'Ted Ginn Jr.': 4800,
#   'Terrelle Pryor': 3700,
#   'Tim Patrick': 3000,
#   'Torrey Smith': 3500,
#   "Tre'Quan Smith": 3400,
#   'Trent Sherfield': 3000,
#   'Trent Taylor': 3900,
#   'Tyreek Hill': 7600,
#   'Tyrell Williams': 4400,
#   'Vyncint Smith': 3000,
#   'Will Fuller V': 5300,
#   'Zach Pascal': 3000,
#   'Zay Jones': 3800}}

# %%
SALARY_CAP = 50000

# %%
_vars = {k: LpVariable.dict(k, v, cat="Binary") for k, v in points.items()}

# %%
_vars
# Out:
# {'DST': {'49ers ': DST_49ers_,
#   'Bills ': DST_Bills_,
#   'Broncos ': DST_Broncos_,
#   'Browns ': DST_Browns_,
#   'Buccaneers ': DST_Buccaneers_,
#   'Cardinals ': DST_Cardinals_,
#   'Chargers ': DST_Chargers_,
#   'Chiefs ': DST_Chiefs_,
#   'Colts ': DST_Colts_,
#   'Dolphins ': DST_Dolphins_,
#   'Eagles ': DST_Eagles_,
#   'Falcons ': DST_Falcons_,
#   'Jaguars ': DST_Jaguars_,
#   'Jets ': DST_Jets_,
#   'Lions ': DST_Lions_,
#   'Packers ': DST_Packers_,
#   'Panthers ': DST_Panthers_,
#   'Patriots ': DST_Patriots_,
#   'Raiders ': DST_Raiders_,
#   'Rams ': DST_Rams_,
#   'Redskins ': DST_Redskins_,
#   'Saints ': DST_Saints_,
#   'Steelers ': DST_Steelers_,
#   'Texans ': DST_Texans_,
#   'Titans ': DST_Titans_,
#   'Vikings ': DST_Vikings_},
#  'FLEX': {'A.J. Derby': FLEX_A.J._Derby,
#   'Aaron Jones': FLEX_Aaron_Jones,
#   'Adam Humphries': FLEX_Adam_Humphries,
#   'Adam Thielen': FLEX_Adam_Thielen,
#   'Adrian Peterson': FLEX_Adrian_Peterson,
#   'Alan Cross': FLEX_Alan_Cross,
#   'Albert Wilson': FLEX_Albert_Wilson,
#   'Alex Armah': FLEX_Alex_Armah,
#   'Alex Ellis': FLEX_Alex_Ellis,
#   'Alfred Blue': FLEX_Alfred_Blue,
#   'Alfred Morris': FLEX_Alfred_Morris,
#   'Alvin Kamara': FLEX_Alvin_Kamara,
#   'Amari Cooper': FLEX_Amari_Cooper,
#   'Ameer Abdullah': FLEX_Ameer_Abdullah,
#   'Andre Holmes': FLEX_Andre_Holmes,
#   'Andre Roberts': FLEX_Andre_Roberts,
#   'Andy Janovich': FLEX_Andy_Janovich,
#   'Anthony Firkser': FLEX_Anthony_Firkser,
#   'Anthony Sherman': FLEX_Anthony_Sherman,
#   'Antonio Brown': FLEX_Antonio_Brown,
#   'Antonio Callaway': FLEX_Antonio_Callaway,
#   'Antony Auclair': FLEX_Antony_Auclair,
#   'ArDarius Stewart': FLEX_ArDarius_Stewart,
#   'Austin Carr': FLEX_Austin_Carr,
#   'Austin Ekeler': FLEX_Austin_Ekeler,
#   'Austin Hooper': FLEX_Austin_Hooper,
#   'Austin Seferian-Jenkins': FLEX_Austin_Seferian_Jenkins,
#   'Beau Brinkley': FLEX_Beau_Brinkley,
#   'Benjamin Watson': FLEX_Benjamin_Watson,
#   'Bilal Powell': FLEX_Bilal_Powell,
#   'Bradley Marquez': FLEX_Bradley_Marquez,
#   'Brandin Cooks': FLEX_Brandin_Cooks,
#   'Brandon Bolden': FLEX_Brandon_Bolden,
#   'Brandon LaFell': FLEX_Brandon_LaFell,
#   'Brandon Powell': FLEX_Brandon_Powell,
#   'Brandon Zylstra': FLEX_Brandon_Zylstra,
#   'Bruce Ellington': FLEX_Bruce_Ellington,
#   'Buddy Howell': FLEX_Buddy_Howell,
#   'C.J. Anderson': FLEX_C.J._Anderson,
#   'C.J. Ham': FLEX_C.J._Ham,
#   'Calvin Ridley': FLEX_Calvin_Ridley,
#   'Cameron Artis-Payne': FLEX_Cameron_Artis_Payne,
#   'Cameron Batson': FLEX_Cameron_Batson,
#   'Cameron Brate': FLEX_Cameron_Brate,
#   'Cameron Meredith': FLEX_Cameron_Meredith,
#   'Carlos Hyde': FLEX_Carlos_Hyde,
#   'Chad Hansen': FLEX_Chad_Hansen,
#   'Chad Williams': FLEX_Chad_Williams,
#   'Charles Clay': FLEX_Charles_Clay,
#   'Chase Edmonds': FLEX_Chase_Edmonds,
#   'Chester Rogers': FLEX_Chester_Rogers,
#   'Chris Conley': FLEX_Chris_Conley,
#   'Chris Herndon': FLEX_Chris_Herndon,
#   'Chris Hogan': FLEX_Chris_Hogan,
#   'Chris Ivory': FLEX_Chris_Ivory,
#   'Chris Manhertz': FLEX_Chris_Manhertz,
#   'Chris Thompson': FLEX_Chris_Thompson,
#   'Christian Kirk': FLEX_Christian_Kirk,
#   'Christian McCaffrey': FLEX_Christian_McCaffrey,
#   'Christine Michael': FLEX_Christine_Michael,
#   'Cole Wick': FLEX_Cole_Wick,
#   'Cooper Kupp': FLEX_Cooper_Kupp,
#   'Cordarrelle Patterson': FLEX_Cordarrelle_Patterson,
#   'Corey Davis': FLEX_Corey_Davis,
#   'Corey Grant': FLEX_Corey_Grant,
#   'Courtland Sutton': FLEX_Courtland_Sutton,
#   'D.J. Chark Jr.': FLEX_D.J._Chark_Jr.,
#   'D.J. Moore': FLEX_D.J._Moore,
#   'DaeSean Hamilton': FLEX_DaeSean_Hamilton,
#   'Dallas Goedert': FLEX_Dallas_Goedert,
#   'Damien Williams': FLEX_Damien_Williams,
#   'Damion Ratley': FLEX_Damion_Ratley,
#   'Dan Arnold': FLEX_Dan_Arnold,
#   'Danny Amendola': FLEX_Danny_Amendola,
#   'Dante Pettis': FLEX_Dante_Pettis,
#   'Darius Jackson': FLEX_Darius_Jackson,
#   'Darius Jennings': FLEX_Darius_Jennings,
#   'Darrel Williams': FLEX_Darrel_Williams,
#   'Darren Fells': FLEX_Darren_Fells,
#   'Darrius Heyward-Bey': FLEX_Darrius_Heyward_Bey,
#   'Davante Adams': FLEX_Davante_Adams,
#   'David Johnson': FLEX_David_Johnson,
#   'David Njoku': FLEX_David_Njoku,
#   "De'Anthony Thomas": FLEX_De'Anthony_Thomas,
#   'DeAndre Carter': FLEX_DeAndre_Carter,
#   'DeAndre Hopkins': FLEX_DeAndre_Hopkins,
#   'DeAndre Washington': FLEX_DeAndre_Washington,
#   'DeSean Jackson': FLEX_DeSean_Jackson,
#   'DeVante Parker': FLEX_DeVante_Parker,
#   'Dede Westbrook': FLEX_Dede_Westbrook,
#   'Demarcus Robinson': FLEX_Demarcus_Robinson,
#   'Demaryius Thomas': FLEX_Demaryius_Thomas,
#   'Demetrius Harris': FLEX_Demetrius_Harris,
#   'Derek Carrier': FLEX_Derek_Carrier,
#   'Derrick Coleman': FLEX_Derrick_Coleman,
#   'Derrick Henry': FLEX_Derrick_Henry,
#   'Derrick Willies': FLEX_Derrick_Willies,
#   'Detrez Newsome': FLEX_Detrez_Newsome,
#   'Devin Funchess': FLEX_Devin_Funchess,
#   'Devontae Booker': FLEX_Devontae_Booker,
#   'Dion Lewis': FLEX_Dion_Lewis,
#   'Donte Moncrief': FLEX_Donte_Moncrief,
#   'Doug Martin': FLEX_Doug_Martin,
#   'Duke Johnson Jr.': FLEX_Duke_Johnson_Jr.,
#   'Durham Smythe': FLEX_Durham_Smythe,
#   'Dwayne Allen': FLEX_Dwayne_Allen,
#   'Dwayne Harris': FLEX_Dwayne_Harris,
#   'Elijah Hood': FLEX_Elijah_Hood,
#   'Emmanuel Sanders': FLEX_Emmanuel_Sanders,
#   'Equanimeous St. Brown': FLEX_Equanimeous_St._Brown,
#   'Eric Ebron': FLEX_Eric_Ebron,
#   'Eric Saubert': FLEX_Eric_Saubert,
#   'Eric Tomlinson': FLEX_Eric_Tomlinson,
#   'Erik Swoope': FLEX_Erik_Swoope,
#   'Frank Gore': FLEX_Frank_Gore,
#   'Freddie Martino': FLEX_Freddie_Martino,
#   'Gabe Holmes': FLEX_Gabe_Holmes,
#   'Garrett Celek': FLEX_Garrett_Celek,
#   'Gavin Escobar': FLEX_Gavin_Escobar,
#   'George Kittle': FLEX_George_Kittle,
#   'Gerald Everett': FLEX_Gerald_Everett,
#   'Geremy Davis': FLEX_Geremy_Davis,
#   'Geronimo Allison': FLEX_Geronimo_Allison,
#   'Golden Tate': FLEX_Golden_Tate,
#   'Hakeem Valles': FLEX_Hakeem_Valles,
#   'Ian Thomas': FLEX_Ian_Thomas,
#   'Isaiah Crowell': FLEX_Isaiah_Crowell,
#   'Isaiah McKenzie': FLEX_Isaiah_McKenzie,
#   'Ito Smith': FLEX_Ito_Smith,
#   "J'Mon Moore": FLEX_J'Mon_Moore,
#   'J.J. Jones': FLEX_J.J._Jones,
#   'J.J. Nelson': FLEX_J.J._Nelson,
#   'Jacquizz Rodgers': FLEX_Jacquizz_Rodgers,
#   'Jake Butt': FLEX_Jake_Butt,
#   'Jakeem Grant': FLEX_Jakeem_Grant,
#   'Jalen Richard': FLEX_Jalen_Richard,
#   'Jamaal Williams': FLEX_Jamaal_Williams,
#   'James Conner': FLEX_James_Conner,
#   'James Develin': FLEX_James_Develin,
#   "James O'Shaughnessy": FLEX_James_O'Shaughnessy,
#   'James Washington': FLEX_James_Washington,
#   'James White': FLEX_James_White,
#   'James Winchester': FLEX_James_Winchester,
#   'Jamison Crowder': FLEX_Jamison_Crowder,
#   'Jared Cook': FLEX_Jared_Cook,
#   'Jarius Wright': FLEX_Jarius_Wright,
#   'Jarvis Landry': FLEX_Jarvis_Landry,
#   'Jason Croom': FLEX_Jason_Croom,
#   'Jaydon Mickens': FLEX_Jaydon_Mickens,
#   'Jaylen Samuels': FLEX_Jaylen_Samuels,
#   'Jeff Heuerman': FLEX_Jeff_Heuerman,
#   'Jeremy Kerley': FLEX_Jeremy_Kerley,
#   'Jeremy Sprinkle': FLEX_Jeremy_Sprinkle,
#   'Jermaine Kearse': FLEX_Jermaine_Kearse,
#   'Jesse James': FLEX_Jesse_James,
#   'Jimmy Graham': FLEX_Jimmy_Graham,
#   'John Kelly': FLEX_John_Kelly,
#   'Johnny Mundt': FLEX_Johnny_Mundt,
#   'Jonathan Williams': FLEX_Jonathan_Williams,
#   'Jonnu Smith': FLEX_Jonnu_Smith,
#   'Jordan Akins': FLEX_Jordan_Akins,
#   'Jordan Leggett': FLEX_Jordan_Leggett,
#   'Jordan Reed': FLEX_Jordan_Reed,
#   'Jordan Thomas': FLEX_Jordan_Thomas,
#   'Jordan Wilkins': FLEX_Jordan_Wilkins,
#   'Jordy Nelson': FLEX_Jordy_Nelson,
#   'Josh Doctson': FLEX_Josh_Doctson,
#   'Josh Hill': FLEX_Josh_Hill,
#   'Josh Reynolds': FLEX_Josh_Reynolds,
#   'Joshua Perkins': FLEX_Joshua_Perkins,
#   'JuJu Smith-Schuster': FLEX_JuJu_Smith_Schuster,
#   'Julio Jones': FLEX_Julio_Jones,
#   'Justin Davis': FLEX_Justin_Davis,
#   'Justin Hardy': FLEX_Justin_Hardy,
#   'Justin Hunter': FLEX_Justin_Hunter,
#   'Justin Watson': FLEX_Justin_Watson,
#   'Kalen Ballage': FLEX_Kalen_Ballage,
#   'Kareem Hunt': FLEX_Kareem_Hunt,
#   'Keelan Cole': FLEX_Keelan_Cole,
#   'Keenan Allen': FLEX_Keenan_Allen,
#   'Keith Smith': FLEX_Keith_Smith,
#   'Kelvin Benjamin': FLEX_Kelvin_Benjamin,
#   'Kendrick Bourne': FLEX_Kendrick_Bourne,
#   'Kenny Golladay': FLEX_Kenny_Golladay,
#   'Kenny Stills': FLEX_Kenny_Stills,
#   'Kenyan Drake': FLEX_Kenyan_Drake,
#   'Keon Hatcher': FLEX_Keon_Hatcher,
#   'Kerryon Johnson': FLEX_Kerryon_Johnson,
#   'Kevin McDermott': FLEX_Kevin_McDermott,
#   'Khari Lee': FLEX_Khari_Lee,
#   'Kyle Juszczyk': FLEX_Kyle_Juszczyk,
#   'Kyle Nelson': FLEX_Kyle_Nelson,
#   'Kyle Rudolph': FLEX_Kyle_Rudolph,
#   'Lamar Miller': FLEX_Lamar_Miller,
#   'Lance Kendricks': FLEX_Lance_Kendricks,
#   'Laquon Treadwell': FLEX_Laquon_Treadwell,
#   'Latavius Murray': FLEX_Latavius_Murray,
#   'LeGarrette Blount': FLEX_LeGarrette_Blount,
#   'Lee Smith': FLEX_Lee_Smith,
#   'Levine Toilolo': FLEX_Levine_Toilolo,
#   'Logan Paulsen': FLEX_Logan_Paulsen,
#   'Logan Thomas': FLEX_Logan_Thomas,
#   'Luke Stocker': FLEX_Luke_Stocker,
#   'Luke Willson': FLEX_Luke_Willson,
#   'Malcolm Brown': FLEX_Malcolm_Brown,
#   'Marcedes Lewis': FLEX_Marcedes_Lewis,
#   'Marcus Johnson': FLEX_Marcus_Johnson,
#   'Marcus Kemp': FLEX_Marcus_Kemp,
#   'Marcus Murphy': FLEX_Marcus_Murphy,
#   'Markus Wheaton': FLEX_Markus_Wheaton,
#   'Marquez Valdes-Scantling': FLEX_Marquez_Valdes_Scantling,
#   'Marshawn Lynch': FLEX_Marshawn_Lynch,
#   'Marvin Hall': FLEX_Marvin_Hall,
#   'Matt Breida': FLEX_Matt_Breida,
#   'Matt Hazel': FLEX_Matt_Hazel,
#   'Matt LaCosse': FLEX_Matt_LaCosse,
#   'Matthew Slater': FLEX_Matthew_Slater,
#   'Melvin Gordon III': FLEX_Melvin_Gordon_III,
#   'Michael Roberts': FLEX_Michael_Roberts,
#   'Michael Thomas': FLEX_Michael_Thomas,
#   'Mike Evans': FLEX_Mike_Evans,
#   'Mike Gesicki': FLEX_Mike_Gesicki,
#   'Mike Gillislee': FLEX_Mike_Gillislee,
#   'Mike Williams': FLEX_Mike_Williams,
#   'Mohamed Sanu': FLEX_Mohamed_Sanu,
#   'Nelson Agholor': FLEX_Nelson_Agholor,
#   'Nick Bellore': FLEX_Nick_Bellore,
#   'Nick Chubb': FLEX_Nick_Chubb,
#   'Niles Paul': FLEX_Niles_Paul,
#   'Nyheim Hines': FLEX_Nyheim_Hines,
#   'O.J. Howard': FLEX_O.J._Howard,
#   'Orson Charles': FLEX_Orson_Charles,
#   'Patrick DiMarco': FLEX_Patrick_DiMarco,
#   'Peyton Barber': FLEX_Peyton_Barber,
#   'Phillip Dorsett': FLEX_Phillip_Dorsett,
#   'Phillip Lindsay': FLEX_Phillip_Lindsay,
#   'Pierre Garcon': FLEX_Pierre_Garcon,
#   'Quincy Enunwa': FLEX_Quincy_Enunwa,
#   'Raheem Mostert': FLEX_Raheem_Mostert,
#   'Randall Cobb': FLEX_Randall_Cobb,
#   'Rashad Greene Sr.': FLEX_Rashad_Greene_Sr.,
#   'Rashard Higgins': FLEX_Rashard_Higgins,
#   'Rex Burkhead': FLEX_Rex_Burkhead,
#   'Richie James Jr.': FLEX_Richie_James_Jr.,
#   'Ricky Ortiz': FLEX_Ricky_Ortiz,
#   'Ricky Seals-Jones': FLEX_Ricky_Seals_Jones,
#   'Riley McCarron': FLEX_Riley_McCarron,
#   'Rishard Matthews': FLEX_Rishard_Matthews,
#   'Rob Gronkowski': FLEX_Rob_Gronkowski,
#   'Robby Anderson': FLEX_Robby_Anderson,
#   'Robert Foster': FLEX_Robert_Foster,
#   'Robert Tonyan': FLEX_Robert_Tonyan,
#   'Robert Woods': FLEX_Robert_Woods,
#   'Roc Thomas': FLEX_Roc_Thomas,
#   'Ronald Jones II': FLEX_Ronald_Jones_II,
#   'Roosevelt Nix': FLEX_Roosevelt_Nix,
#   'Royce Freeman': FLEX_Royce_Freeman,
#   'Russell Gage': FLEX_Russell_Gage,
#   'Ryan Grant': FLEX_Ryan_Grant,
#   'Ryan Griffin': FLEX_Ryan_Griffin,
#   'Ryan Hewitt': FLEX_Ryan_Hewitt,
#   'Ryan Switzer': FLEX_Ryan_Switzer,
#   'Samaje Perine': FLEX_Samaje_Perine,
#   'Sammy Watkins': FLEX_Sammy_Watkins,
#   'Sean Culkin': FLEX_Sean_Culkin,
#   'Senorise Perry': FLEX_Senorise_Perry,
#   'Seth Roberts': FLEX_Seth_Roberts,
#   'Shaun Wilson': FLEX_Shaun_Wilson,
#   'Shelton Gibson': FLEX_Shelton_Gibson,
#   'Sony Michel': FLEX_Sony_Michel,
#   'Stacy Coley': FLEX_Stacy_Coley,
#   'Stefon Diggs': FLEX_Stefon_Diggs,
#   'Stevan Ridley': FLEX_Stevan_Ridley,
#   'T.J. Logan': FLEX_T.J._Logan,
#   'T.Y. Hilton': FLEX_T.Y._Hilton,
#   'TJ Jones': FLEX_TJ_Jones,
#   'Tajae Sharpe': FLEX_Tajae_Sharpe,
#   'Tanner McEvoy': FLEX_Tanner_McEvoy,
#   'Taywan Taylor': FLEX_Taywan_Taylor,
#   'Ted Ginn Jr.': FLEX_Ted_Ginn_Jr.,
#   'Terrelle Pryor': FLEX_Terrelle_Pryor,
#   'Tevin Coleman': FLEX_Tevin_Coleman,
#   'Theo Riddick': FLEX_Theo_Riddick,
#   'Tim Patrick': FLEX_Tim_Patrick,
#   'Todd Gurley II': FLEX_Todd_Gurley_II,
#   'Tommy Bohanon': FLEX_Tommy_Bohanon,
#   'Torrey Smith': FLEX_Torrey_Smith,
#   'Travis Kelce': FLEX_Travis_Kelce,
#   "Tre'Quan Smith": FLEX_Tre'Quan_Smith,
#   'Trent Sherfield': FLEX_Trent_Sherfield,
#   'Trent Taylor': FLEX_Trent_Taylor,
#   'Trenton Cannon': FLEX_Trenton_Cannon,
#   'Ty Montgomery': FLEX_Ty_Montgomery,
#   'Tyler Conklin': FLEX_Tyler_Conklin,
#   'Tyler Ervin': FLEX_Tyler_Ervin,
#   'Tyler Higbee': FLEX_Tyler_Higbee,
#   'Tyreek Hill': FLEX_Tyreek_Hill,
#   'Tyrell Williams': FLEX_Tyrell_Williams,
#   'Vance McDonald': FLEX_Vance_McDonald,
#   'Vernon Davis': FLEX_Vernon_Davis,
#   'Virgil Green': FLEX_Virgil_Green,
#   'Vyncint Smith': FLEX_Vyncint_Smith,
#   'Wendell Smallwood': FLEX_Wendell_Smallwood,
#   'Will Fuller V': FLEX_Will_Fuller_V,
#   'Xavier Grimble': FLEX_Xavier_Grimble,
#   'Zach Ertz': FLEX_Zach_Ertz,
#   'Zach Line': FLEX_Zach_Line,
#   'Zach Pascal': FLEX_Zach_Pascal,
#   'Zay Jones': FLEX_Zay_Jones},
#  'QB': {'AJ McCarron': QB_AJ_McCarron,
#   'Alex Smith': QB_Alex_Smith,
#   'Andrew Luck': QB_Andrew_Luck,
#   'Baker Mayfield': QB_Baker_Mayfield,
#   'Ben Roethlisberger': QB_Ben_Roethlisberger,
#   'Blaine Gabbert': QB_Blaine_Gabbert,
#   'Blake Bortles': QB_Blake_Bortles,
#   'Brandon Allen': QB_Brandon_Allen,
#   'Brandon Weeden': QB_Brandon_Weeden,
#   'Brian Hoyer': QB_Brian_Hoyer,
#   'Brock Osweiler': QB_Brock_Osweiler,
#   'C.J. Beathard': QB_C.J._Beathard,
#   'Cam Newton': QB_Cam_Newton,
#   'Carson Wentz': QB_Carson_Wentz,
#   'Case Keenum': QB_Case_Keenum,
#   'Chad Henne': QB_Chad_Henne,
#   'Chad Kelly': QB_Chad_Kelly,
#   'Cody Kessler': QB_Cody_Kessler,
#   'Colt McCoy': QB_Colt_McCoy,
#   'David Fales': QB_David_Fales,
#   'DeShone Kizer': QB_DeShone_Kizer,
#   'Derek Carr': QB_Derek_Carr,
#   'Deshaun Watson': QB_Deshaun_Watson,
#   'Drew Brees': QB_Drew_Brees,
#   'Geno Smith': QB_Geno_Smith,
#   'Jacoby Brissett': QB_Jacoby_Brissett,
#   'Jared Goff': QB_Jared_Goff,
#   'Jimmy Garoppolo': QB_Jimmy_Garoppolo,
#   'Joe Webb III': QB_Joe_Webb_III,
#   'Josh Allen': QB_Josh_Allen,
#   'Josh McCown': QB_Josh_McCown,
#   'Josh Rosen': QB_Josh_Rosen,
#   'Joshua Dobbs': QB_Joshua_Dobbs,
#   'Kevin Hogan': QB_Kevin_Hogan,
#   'Kirk Cousins': QB_Kirk_Cousins,
#   'Kyle Sloter': QB_Kyle_Sloter,
#   'Luke Falk': QB_Luke_Falk,
#   'Mason Rudolph': QB_Mason_Rudolph,
#   'Matt Cassel': QB_Matt_Cassel,
#   'Matt Ryan': QB_Matt_Ryan,
#   'Matt Schaub': QB_Matt_Schaub,
#   'Matthew Stafford': QB_Matthew_Stafford,
#   'Mike Glennon': QB_Mike_Glennon,
#   'Nate Sudfeld': QB_Nate_Sudfeld,
#   'Nathan Peterman': QB_Nathan_Peterman,
#   'Nick Foles': QB_Nick_Foles,
#   'Patrick Mahomes': QB_Patrick_Mahomes,
#   'Philip Rivers': QB_Philip_Rivers,
#   'Ryan Fitzpatrick': QB_Ryan_Fitzpatrick,
#   'Ryan Griffin': QB_Ryan_Griffin,
#   'Ryan Tannehill': QB_Ryan_Tannehill,
#   'Sam Bradford': QB_Sam_Bradford,
#   'Sam Darnold': QB_Sam_Darnold,
#   'Sean Mannion': QB_Sean_Mannion,
#   'Taylor Heinicke': QB_Taylor_Heinicke,
#   'Taysom Hill': QB_Taysom_Hill,
#   'Teddy Bridgewater': QB_Teddy_Bridgewater,
#   'Tim Boyle': QB_Tim_Boyle,
#   'Tom Brady': QB_Tom_Brady,
#   'Trevor Siemian': QB_Trevor_Siemian},
#  'RB': {'Aaron Jones': RB_Aaron_Jones,
#   'Adrian Peterson': RB_Adrian_Peterson,
#   'Alex Armah': RB_Alex_Armah,
#   'Alfred Blue': RB_Alfred_Blue,
#   'Alfred Morris': RB_Alfred_Morris,
#   'Alvin Kamara': RB_Alvin_Kamara,
#   'Ameer Abdullah': RB_Ameer_Abdullah,
#   'Andy Janovich': RB_Andy_Janovich,
#   'Anthony Sherman': RB_Anthony_Sherman,
#   'Austin Ekeler': RB_Austin_Ekeler,
#   'Bilal Powell': RB_Bilal_Powell,
#   'Brandon Bolden': RB_Brandon_Bolden,
#   'Buddy Howell': RB_Buddy_Howell,
#   'C.J. Anderson': RB_C.J._Anderson,
#   'C.J. Ham': RB_C.J._Ham,
#   'Cameron Artis-Payne': RB_Cameron_Artis_Payne,
#   'Carlos Hyde': RB_Carlos_Hyde,
#   'Chase Edmonds': RB_Chase_Edmonds,
#   'Chris Ivory': RB_Chris_Ivory,
#   'Chris Thompson': RB_Chris_Thompson,
#   'Christian McCaffrey': RB_Christian_McCaffrey,
#   'Christine Michael': RB_Christine_Michael,
#   'Corey Grant': RB_Corey_Grant,
#   'Damien Williams': RB_Damien_Williams,
#   'Darius Jackson': RB_Darius_Jackson,
#   'Darrel Williams': RB_Darrel_Williams,
#   'David Johnson': RB_David_Johnson,
#   'DeAndre Washington': RB_DeAndre_Washington,
#   'Derrick Coleman': RB_Derrick_Coleman,
#   'Derrick Henry': RB_Derrick_Henry,
#   'Detrez Newsome': RB_Detrez_Newsome,
#   'Devontae Booker': RB_Devontae_Booker,
#   'Dion Lewis': RB_Dion_Lewis,
#   'Doug Martin': RB_Doug_Martin,
#   'Duke Johnson Jr.': RB_Duke_Johnson_Jr.,
#   'Elijah Hood': RB_Elijah_Hood,
#   'Frank Gore': RB_Frank_Gore,
#   'Isaiah Crowell': RB_Isaiah_Crowell,
#   'Ito Smith': RB_Ito_Smith,
#   'Jacquizz Rodgers': RB_Jacquizz_Rodgers,
#   'Jalen Richard': RB_Jalen_Richard,
#   'Jamaal Williams': RB_Jamaal_Williams,
#   'James Conner': RB_James_Conner,
#   'James Develin': RB_James_Develin,
#   'James White': RB_James_White,
#   'Jaylen Samuels': RB_Jaylen_Samuels,
#   'John Kelly': RB_John_Kelly,
#   'Jonathan Williams': RB_Jonathan_Williams,
#   'Jordan Wilkins': RB_Jordan_Wilkins,
#   'Justin Davis': RB_Justin_Davis,
#   'Kalen Ballage': RB_Kalen_Ballage,
#   'Kareem Hunt': RB_Kareem_Hunt,
#   'Keith Smith': RB_Keith_Smith,
#   'Kenyan Drake': RB_Kenyan_Drake,
#   'Kerryon Johnson': RB_Kerryon_Johnson,
#   'Kyle Juszczyk': RB_Kyle_Juszczyk,
#   'Lamar Miller': RB_Lamar_Miller,
#   'Latavius Murray': RB_Latavius_Murray,
#   'LeGarrette Blount': RB_LeGarrette_Blount,
#   'Malcolm Brown': RB_Malcolm_Brown,
#   'Marcus Murphy': RB_Marcus_Murphy,
#   'Marshawn Lynch': RB_Marshawn_Lynch,
#   'Matt Breida': RB_Matt_Breida,
#   'Melvin Gordon III': RB_Melvin_Gordon_III,
#   'Mike Gillislee': RB_Mike_Gillislee,
#   'Nick Bellore': RB_Nick_Bellore,
#   'Nick Chubb': RB_Nick_Chubb,
#   'Nyheim Hines': RB_Nyheim_Hines,
#   'Patrick DiMarco': RB_Patrick_DiMarco,
#   'Peyton Barber': RB_Peyton_Barber,
#   'Phillip Lindsay': RB_Phillip_Lindsay,
#   'Raheem Mostert': RB_Raheem_Mostert,
#   'Rex Burkhead': RB_Rex_Burkhead,
#   'Ricky Ortiz': RB_Ricky_Ortiz,
#   'Roc Thomas': RB_Roc_Thomas,
#   'Ronald Jones II': RB_Ronald_Jones_II,
#   'Roosevelt Nix': RB_Roosevelt_Nix,
#   'Royce Freeman': RB_Royce_Freeman,
#   'Samaje Perine': RB_Samaje_Perine,
#   'Senorise Perry': RB_Senorise_Perry,
#   'Shaun Wilson': RB_Shaun_Wilson,
#   'Sony Michel': RB_Sony_Michel,
#   'Stevan Ridley': RB_Stevan_Ridley,
#   'T.J. Logan': RB_T.J._Logan,
#   'Tevin Coleman': RB_Tevin_Coleman,
#   'Theo Riddick': RB_Theo_Riddick,
#   'Todd Gurley II': RB_Todd_Gurley_II,
#   'Tommy Bohanon': RB_Tommy_Bohanon,
#   'Trenton Cannon': RB_Trenton_Cannon,
#   'Ty Montgomery': RB_Ty_Montgomery,
#   'Tyler Ervin': RB_Tyler_Ervin,
#   'Wendell Smallwood': RB_Wendell_Smallwood,
#   'Zach Line': RB_Zach_Line},
#  'TE': {'A.J. Derby': TE_A.J._Derby,
#   'Alan Cross': TE_Alan_Cross,
#   'Alex Ellis': TE_Alex_Ellis,
#   'Anthony Firkser': TE_Anthony_Firkser,
#   'Antony Auclair': TE_Antony_Auclair,
#   'Austin Hooper': TE_Austin_Hooper,
#   'Austin Seferian-Jenkins': TE_Austin_Seferian_Jenkins,
#   'Beau Brinkley': TE_Beau_Brinkley,
#   'Benjamin Watson': TE_Benjamin_Watson,
#   'Cameron Brate': TE_Cameron_Brate,
#   'Charles Clay': TE_Charles_Clay,
#   'Chris Herndon': TE_Chris_Herndon,
#   'Chris Manhertz': TE_Chris_Manhertz,
#   'Cole Wick': TE_Cole_Wick,
#   'Dallas Goedert': TE_Dallas_Goedert,
#   'Dan Arnold': TE_Dan_Arnold,
#   'Darren Fells': TE_Darren_Fells,
#   'David Njoku': TE_David_Njoku,
#   'Demetrius Harris': TE_Demetrius_Harris,
#   'Derek Carrier': TE_Derek_Carrier,
#   'Durham Smythe': TE_Durham_Smythe,
#   'Dwayne Allen': TE_Dwayne_Allen,
#   'Eric Ebron': TE_Eric_Ebron,
#   'Eric Saubert': TE_Eric_Saubert,
#   'Eric Tomlinson': TE_Eric_Tomlinson,
#   'Erik Swoope': TE_Erik_Swoope,
#   'Gabe Holmes': TE_Gabe_Holmes,
#   'Garrett Celek': TE_Garrett_Celek,
#   'Gavin Escobar': TE_Gavin_Escobar,
#   'George Kittle': TE_George_Kittle,
#   'Gerald Everett': TE_Gerald_Everett,
#   'Hakeem Valles': TE_Hakeem_Valles,
#   'Ian Thomas': TE_Ian_Thomas,
#   'Jake Butt': TE_Jake_Butt,
#   "James O'Shaughnessy": TE_James_O'Shaughnessy,
#   'James Winchester': TE_James_Winchester,
#   'Jared Cook': TE_Jared_Cook,
#   'Jason Croom': TE_Jason_Croom,
#   'Jeff Heuerman': TE_Jeff_Heuerman,
#   'Jeremy Sprinkle': TE_Jeremy_Sprinkle,
#   'Jesse James': TE_Jesse_James,
#   'Jimmy Graham': TE_Jimmy_Graham,
#   'Johnny Mundt': TE_Johnny_Mundt,
#   'Jonnu Smith': TE_Jonnu_Smith,
#   'Jordan Akins': TE_Jordan_Akins,
#   'Jordan Leggett': TE_Jordan_Leggett,
#   'Jordan Reed': TE_Jordan_Reed,
#   'Jordan Thomas': TE_Jordan_Thomas,
#   'Josh Hill': TE_Josh_Hill,
#   'Joshua Perkins': TE_Joshua_Perkins,
#   'Kevin McDermott': TE_Kevin_McDermott,
#   'Khari Lee': TE_Khari_Lee,
#   'Kyle Nelson': TE_Kyle_Nelson,
#   'Kyle Rudolph': TE_Kyle_Rudolph,
#   'Lance Kendricks': TE_Lance_Kendricks,
#   'Lee Smith': TE_Lee_Smith,
#   'Levine Toilolo': TE_Levine_Toilolo,
#   'Logan Paulsen': TE_Logan_Paulsen,
#   'Logan Thomas': TE_Logan_Thomas,
#   'Luke Stocker': TE_Luke_Stocker,
#   'Luke Willson': TE_Luke_Willson,
#   'Marcedes Lewis': TE_Marcedes_Lewis,
#   'Matt LaCosse': TE_Matt_LaCosse,
#   'Michael Roberts': TE_Michael_Roberts,
#   'Mike Gesicki': TE_Mike_Gesicki,
#   'Niles Paul': TE_Niles_Paul,
#   'O.J. Howard': TE_O.J._Howard,
#   'Orson Charles': TE_Orson_Charles,
#   'Ricky Seals-Jones': TE_Ricky_Seals_Jones,
#   'Rob Gronkowski': TE_Rob_Gronkowski,
#   'Robert Tonyan': TE_Robert_Tonyan,
#   'Ryan Griffin': TE_Ryan_Griffin,
#   'Ryan Hewitt': TE_Ryan_Hewitt,
#   'Sean Culkin': TE_Sean_Culkin,
#   'Travis Kelce': TE_Travis_Kelce,
#   'Tyler Conklin': TE_Tyler_Conklin,
#   'Tyler Higbee': TE_Tyler_Higbee,
#   'Vance McDonald': TE_Vance_McDonald,
#   'Vernon Davis': TE_Vernon_Davis,
#   'Virgil Green': TE_Virgil_Green,
#   'Xavier Grimble': TE_Xavier_Grimble,
#   'Zach Ertz': TE_Zach_Ertz},
#  'WR': {'Adam Humphries': WR_Adam_Humphries,
#   'Adam Thielen': WR_Adam_Thielen,
#   'Albert Wilson': WR_Albert_Wilson,
#   'Amari Cooper': WR_Amari_Cooper,
#   'Andre Holmes': WR_Andre_Holmes,
#   'Andre Roberts': WR_Andre_Roberts,
#   'Antonio Brown': WR_Antonio_Brown,
#   'Antonio Callaway': WR_Antonio_Callaway,
#   'ArDarius Stewart': WR_ArDarius_Stewart,
#   'Austin Carr': WR_Austin_Carr,
#   'Bradley Marquez': WR_Bradley_Marquez,
#   'Brandin Cooks': WR_Brandin_Cooks,
#   'Brandon LaFell': WR_Brandon_LaFell,
#   'Brandon Powell': WR_Brandon_Powell,
#   'Brandon Zylstra': WR_Brandon_Zylstra,
#   'Bruce Ellington': WR_Bruce_Ellington,
#   'Calvin Ridley': WR_Calvin_Ridley,
#   'Cameron Batson': WR_Cameron_Batson,
#   'Cameron Meredith': WR_Cameron_Meredith,
#   'Chad Hansen': WR_Chad_Hansen,
#   'Chad Williams': WR_Chad_Williams,
#   'Chester Rogers': WR_Chester_Rogers,
#   'Chris Conley': WR_Chris_Conley,
#   'Chris Hogan': WR_Chris_Hogan,
#   'Christian Kirk': WR_Christian_Kirk,
#   'Cooper Kupp': WR_Cooper_Kupp,
#   'Cordarrelle Patterson': WR_Cordarrelle_Patterson,
#   'Corey Davis': WR_Corey_Davis,
#   'Courtland Sutton': WR_Courtland_Sutton,
#   'D.J. Chark Jr.': WR_D.J._Chark_Jr.,
#   'D.J. Moore': WR_D.J._Moore,
#   'DaeSean Hamilton': WR_DaeSean_Hamilton,
#   'Damion Ratley': WR_Damion_Ratley,
#   'Danny Amendola': WR_Danny_Amendola,
#   'Dante Pettis': WR_Dante_Pettis,
#   'Darius Jennings': WR_Darius_Jennings,
#   'Darrius Heyward-Bey': WR_Darrius_Heyward_Bey,
#   'Davante Adams': WR_Davante_Adams,
#   "De'Anthony Thomas": WR_De'Anthony_Thomas,
#   'DeAndre Carter': WR_DeAndre_Carter,
#   'DeAndre Hopkins': WR_DeAndre_Hopkins,
#   'DeSean Jackson': WR_DeSean_Jackson,
#   'DeVante Parker': WR_DeVante_Parker,
#   'Dede Westbrook': WR_Dede_Westbrook,
#   'Demarcus Robinson': WR_Demarcus_Robinson,
#   'Demaryius Thomas': WR_Demaryius_Thomas,
#   'Derrick Willies': WR_Derrick_Willies,
#   'Devin Funchess': WR_Devin_Funchess,
#   'Donte Moncrief': WR_Donte_Moncrief,
#   'Dwayne Harris': WR_Dwayne_Harris,
#   'Emmanuel Sanders': WR_Emmanuel_Sanders,
#   'Equanimeous St. Brown': WR_Equanimeous_St._Brown,
#   'Freddie Martino': WR_Freddie_Martino,
#   'Geremy Davis': WR_Geremy_Davis,
#   'Geronimo Allison': WR_Geronimo_Allison,
#   'Golden Tate': WR_Golden_Tate,
#   'Isaiah McKenzie': WR_Isaiah_McKenzie,
#   "J'Mon Moore": WR_J'Mon_Moore,
#   'J.J. Jones': WR_J.J._Jones,
#   'J.J. Nelson': WR_J.J._Nelson,
#   'Jakeem Grant': WR_Jakeem_Grant,
#   'James Washington': WR_James_Washington,
#   'Jamison Crowder': WR_Jamison_Crowder,
#   'Jarius Wright': WR_Jarius_Wright,
#   'Jarvis Landry': WR_Jarvis_Landry,
#   'Jaydon Mickens': WR_Jaydon_Mickens,
#   'Jeremy Kerley': WR_Jeremy_Kerley,
#   'Jermaine Kearse': WR_Jermaine_Kearse,
#   'Jordy Nelson': WR_Jordy_Nelson,
#   'Josh Doctson': WR_Josh_Doctson,
#   'Josh Reynolds': WR_Josh_Reynolds,
#   'JuJu Smith-Schuster': WR_JuJu_Smith_Schuster,
#   'Julio Jones': WR_Julio_Jones,
#   'Justin Hardy': WR_Justin_Hardy,
#   'Justin Hunter': WR_Justin_Hunter,
#   'Justin Watson': WR_Justin_Watson,
#   'Keelan Cole': WR_Keelan_Cole,
#   'Keenan Allen': WR_Keenan_Allen,
#   'Kelvin Benjamin': WR_Kelvin_Benjamin,
#   'Kendrick Bourne': WR_Kendrick_Bourne,
#   'Kenny Golladay': WR_Kenny_Golladay,
#   'Kenny Stills': WR_Kenny_Stills,
#   'Keon Hatcher': WR_Keon_Hatcher,
#   'Laquon Treadwell': WR_Laquon_Treadwell,
#   'Marcus Johnson': WR_Marcus_Johnson,
#   'Marcus Kemp': WR_Marcus_Kemp,
#   'Markus Wheaton': WR_Markus_Wheaton,
#   'Marquez Valdes-Scantling': WR_Marquez_Valdes_Scantling,
#   'Marvin Hall': WR_Marvin_Hall,
#   'Matt Hazel': WR_Matt_Hazel,
#   'Matthew Slater': WR_Matthew_Slater,
#   'Michael Thomas': WR_Michael_Thomas,
#   'Mike Evans': WR_Mike_Evans,
#   'Mike Williams': WR_Mike_Williams,
#   'Mohamed Sanu': WR_Mohamed_Sanu,
#   'Nelson Agholor': WR_Nelson_Agholor,
#   'Phillip Dorsett': WR_Phillip_Dorsett,
#   'Pierre Garcon': WR_Pierre_Garcon,
#   'Quincy Enunwa': WR_Quincy_Enunwa,
#   'Randall Cobb': WR_Randall_Cobb,
#   'Rashad Greene Sr.': WR_Rashad_Greene_Sr.,
#   'Rashard Higgins': WR_Rashard_Higgins,
#   'Richie James Jr.': WR_Richie_James_Jr.,
#   'Riley McCarron': WR_Riley_McCarron,
#   'Rishard Matthews': WR_Rishard_Matthews,
#   'Robby Anderson': WR_Robby_Anderson,
#   'Robert Foster': WR_Robert_Foster,
#   'Robert Woods': WR_Robert_Woods,
#   'Russell Gage': WR_Russell_Gage,
#   'Ryan Grant': WR_Ryan_Grant,
#   'Ryan Switzer': WR_Ryan_Switzer,
#   'Sammy Watkins': WR_Sammy_Watkins,
#   'Seth Roberts': WR_Seth_Roberts,
#   'Shelton Gibson': WR_Shelton_Gibson,
#   'Stacy Coley': WR_Stacy_Coley,
#   'Stefon Diggs': WR_Stefon_Diggs,
#   'T.Y. Hilton': WR_T.Y._Hilton,
#   'TJ Jones': WR_TJ_Jones,
#   'Tajae Sharpe': WR_Tajae_Sharpe,
#   'Tanner McEvoy': WR_Tanner_McEvoy,
#   'Taywan Taylor': WR_Taywan_Taylor,
#   'Ted Ginn Jr.': WR_Ted_Ginn_Jr.,
#   'Terrelle Pryor': WR_Terrelle_Pryor,
#   'Tim Patrick': WR_Tim_Patrick,
#   'Torrey Smith': WR_Torrey_Smith,
#   "Tre'Quan Smith": WR_Tre'Quan_Smith,
#   'Trent Sherfield': WR_Trent_Sherfield,
#   'Trent Taylor': WR_Trent_Taylor,
#   'Tyreek Hill': WR_Tyreek_Hill,
#   'Tyrell Williams': WR_Tyrell_Williams,
#   'Vyncint Smith': WR_Vyncint_Smith,
#   'Will Fuller V': WR_Will_Fuller_V,
#   'Zach Pascal': WR_Zach_Pascal,
#   'Zay Jones': WR_Zay_Jones}}

# %% [markdown]
# # Solve using Linear Programming Optimization:
# https://www.coin-or.org/PuLP/pulp.html

# %%
prob = LpProblem("Fantasy", LpMaximize)
rewards = []
costs = []
position_constraints = []
# Setting up the reward
for k, v in _vars.items():
    costs += lpSum([salaries[k][i] * _vars[k][i] for i in v])
    rewards += lpSum([points[k][i] * _vars[k][i] for i in v])
    prob += lpSum([_vars[k][i] for i in v]) <= pos_num_available[k]
    
prob += lpSum(rewards)
prob += lpSum(costs) <= SALARY_CAP

# %%
prob.solve()
# Out:
# 1

# %%
def summary(prob):
    div = '---------------------------------------\n'
    print("Variables:\n")
    score = str(prob.objective)
    constraints = [str(const) for const in prob.constraints.values()]
    for v in prob.variables():
        score = score.replace(v.name, str(v.varValue))
        constraints = [const.replace(v.name, str(v.varValue)) for const in constraints]
        if v.varValue != 0:
            print(v.name, "=", v.varValue)
    print(div)
    print("Constraints:")
    for constraint in constraints:
        constraint_pretty = " + ".join(re.findall("[0-9\.]*\*1.0", constraint))
        if constraint_pretty != "":
            print("{} = {}".format(constraint_pretty, eval(constraint_pretty)))
    print(div)
    print("Score:")
    score_pretty = " + ".join(re.findall("[0-9\.]+\*1.0", score))
    print("{} = {}".format(score_pretty, eval(score)))

# %%
summary(prob)
# Out:
# Variables:
#
# DST_Rams_ = 1.0
# FLEX_DeSean_Jackson = 1.0
# QB_Ryan_Fitzpatrick = 1.0
# RB_James_Conner = 1.0
# RB_Melvin_Gordon_III = 1.0
# TE_Jesse_James = 1.0
# WR_DeSean_Jackson = 1.0
# WR_Michael_Thomas = 1.0
# WR_Will_Fuller_V = 1.0
# ---------------------------------------
#
# Constraints:
# 3700*1.0 + 4900*1.0 + 5500*1.0 + 6700*1.0 + 7400*1.0 + 2800*1.0 + 4900*1.0 + 8600*1.0 + 5300*1.0 = 49800.0
# ---------------------------------------
#
# Score:
# 15.0*1.0 + 30.3*1.0 + 39.6*1.0 + 28.9*1.0 + 30.6*1.0 + 18.4*1.0 + 30.3*1.0 + 37.0*1.0 + 28.3*1.0 = 258.40000000000003

# %% [markdown]
# # Solve Greedy:

# %%
def eval_players(players):
    return sum([current[current.displayName == player].iloc[0].points for player in players])
def greedy(val):
    remaining = SALARY_CAP
    positions = current.position.unique()
    best_players = []
    best_so_far = -float("inf")
    for comb_position in permutations(positions):
        players = []
        for pos in comb_position:
            for _ in range(pos_num_available[pos]):
                available = current[(~current.displayName.isin(players)) & 
                                 (current.position == pos) & 
                                 (current.salary <= remaining)]
                if available.size > 0:
                    best = available.sort_values(val,ascending=False).iloc[0]
                    players.append(best.displayName)
                    remaining -= best.salary
        cur_eval = eval_players(players)
        if cur_eval > best_so_far:
            best_players = players
            best_so_far = cur_eval
    return best_players

# %%
greedy_points = greedy("points")
print(greedy_points)
eval_players(greedy_points)
# Out:
# ['Alvin Kamara', 'Melvin Gordon III', 'Michael Thomas', 'Tyreek Hill', 'DeSean Jackson', 'Ryan Fitzpatrick', 'Jared Cook', 'Jets ']
# 234.70000000000002

# %%
greedy_points
# Out:
# ['Alvin Kamara',
#  'Melvin Gordon III',
#  'Michael Thomas',
#  'Tyreek Hill',
#  'DeSean Jackson',
#  'Ryan Fitzpatrick',
#  'Jared Cook',
#  'Jets ']

# %%
points_per_dollar = current.points / current.salary
current["points_per_dollar"] = points_per_dollar
greedy_points = greedy("points_per_dollar")
print(greedy_points)
eval_players(greedy_points)
# Out:
# ['James Conner', 'Austin Ekeler', 'DeSean Jackson', 'Will Fuller V', 'Kenny Golladay', 'Ryan Fitzpatrick', 'Jesse James', 'Browns ', 'Jared Cook']
# 215.1
